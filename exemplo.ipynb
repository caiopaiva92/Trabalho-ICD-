# %%
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup

# %%
def csv_creator(links_meses, ano):
    ids_categorias = [('osversion_details', 'OS Version'), ('cat0_details', 'System RAM'), ('cat2_details', 'Physical CPUs'), ('cat3_details', 'Video Card Description'), ('cat4_details', 'VRAM'), ('cat5_details', 'Primary Display Resolution')]

    with open(f'dados_mensais_{ano}.csv', 'w', encoding='utf-8') as f:
                f.write('Categoria, Especificação, Porcentagens, Incrementos/Decrementos, Mês, Ano\n')

    for link, mes in links_meses:
        time.sleep(5)
        html = requests.get(link).text
        soup = BeautifulSoup(html, 'html.parser')

        for id_, categoria in ids_categorias:
            # Pega apenas a div do id especificado (Os ids tem que ser os details para funcionar)
            div = soup.find('div', id=f'{id_}')

            titulos = div.find_all('div', class_='stats_col_mid')
            porcentagens = div.find_all('div', class_='stats_col_right')
            incs_decs = div.find_all('div', class_='stats_col_right2')

            with open(f'dados_mensais_{ano}.csv', 'a+', encoding='utf-8') as f:
                for titulo, porcentagem, inc_dec in zip(titulos, porcentagens, incs_decs):
                    f.write(f"{categoria}, {titulo.text.strip()}, {porcentagem.text.strip()}, {inc_dec.text.strip()}, {mes}, {ano}\n")

# %%
# Links históricos diretos do servidor da Steam para o ano de 2021 completo
links_2021_completo = [
    ("https://store.steampowered.com/hwsurvey/2021/01/", "Janeiro"),
    ("https://store.steampowered.com/hwsurvey/2021/02/", "Fevereiro"),
    ("https://store.steampowered.com/hwsurvey/2021/03/", "Março"),
    ("https://store.steampowered.com/hwsurvey/2021/04/", "Abril"),
    ("https://store.steampowered.com/hwsurvey/2021/05/", "Maio"),
    ("https://store.steampowered.com/hwsurvey/2021/06/", "Junho"),
    ("https://store.steampowered.com/hwsurvey/2021/07/", "Julho"),
    ("https://store.steampowered.com/hwsurvey/2021/08/", "Agosto"),
    ("https://store.steampowered.com/hwsurvey/2021/09/", "Setembro"),
    ("https://store.steampowered.com/hwsurvey/2021/10/", "Outubro"),
    ("https://store.steampowered.com/hwsurvey/2021/11/", "Novembro"),
    ("https://store.steampowered.com/hwsurvey/2021/12/", "Dezembro"),
]

print("Iniciando a coleta completa de 2021...")
# Chama a função passando a lista completa e o ano 2021
csv_creator(links_2021_completo, 2021)
print("Coleta de 2021 finalizada com sucesso de Janeiro a Dezembro!")
# Out:
# Iniciando a coleta completa de 2021...
# Coleta de 2021 finalizada com sucesso de Janeiro a Dezembro!

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#      RAM  PercApr22  ChangeApr2022
# 0  <4 GB       0.26           0.01
# 1   4 GB       6.76           0.20
# 2   8 GB      24.30           0.86
# 3  12 GB       3.60           0.17
# 4  16 GB      50.59          -0.89
