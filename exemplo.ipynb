# %%
df = pd.read_csv("RAM.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RAM            10 non-null     str
#  1   PercApr22      10 non-null     float64
#  2   ChangeApr2022  10 non-null     float64
# dtypes: float64(2), str(1)
# memory usage: 372.0 bytes

# %%
df.head()
# Out:
#      RAM  PercApr22  ChangeApr2022
# 0  <4 GB       0.26           0.01
# 1   4 GB       6.76           0.20
# 2   8 GB      24.30           0.86
# 3  12 GB       3.60           0.17
# 4  16 GB      50.59          -0.89
